# %% [markdown]
# This notebook is to clean my dataset!

# %%
# !pip3 install -U ucimlrepo 

from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
apartment_for_rent_classified = fetch_ucirepo(id=555) 
  
# data (as pandas dataframes) 
X = apartment_for_rent_classified.data.features 
y = apartment_for_rent_classified.data.targets 
  
# metadata 
print(apartment_for_rent_classified.metadata) 
  
# variable information 
print(apartment_for_rent_classified.variables)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 from ucimlrepo import fetch_ucirepo
#       5 # fetch dataset
# ----> 6 apartment_for_rent_classified = fetch_ucirepo(id=555)
#       8 # data (as pandas dataframes)
#       9 X = apartment_for_rent_classified.data.features
#
# File ~/anaconda3/envs/finalNLP/lib/python3.10/site-packages/ucimlrepo/fetch.py:97, in fetch_ucirepo(name, id)
#      95 df = None
#      96 try:
# ---> 97     df = pd.read_csv(data_url)
#      98 except (urllib.error.URLError, urllib.error.HTTPError):
#      99     raise DatasetNotFoundError('Error reading data csv file for "{}" dataset (id={}).'.format(name, id))
#
# ...

# %%
import pandas as pd

# %%
# Example with low_memory=False
df = pd.read_csv('./apartments_for_rent_classified_100K.csv', encoding = 'ISO-8859–1', delimiter=';')
df.head()
# Out:
# /var/folders/4z/2hhh_brs3r7fjf6fj_zdz66w0000gn/T/ipykernel_26381/3085996021.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./apartments_for_rent_classified_100K.csv', encoding = 'ISO-8859–1', delimiter=';')
#            id                category                            title  \
# 0  5668640009  housing/rent/apartment       One BR 507 & 509 Esplanade
# 1  5668639818  housing/rent/apartment      Three BR 146 Lochview Drive
# 2  5668639686  housing/rent/apartment  Three BR 3101 Morningside Drive
# 3  5668639659  housing/rent/apartment            Two BR 209 Aegean Way
# 4  5668639374  housing/rent/apartment         One BR 4805 Marquette NE
#
#                                                 body amenities  bathrooms  \
# 0  This unit is located at 507 & 509 Esplanade, R...       NaN        1.0
# 1  This unit is located at 146 Lochview Drive, Ne...       NaN        1.5
# ...

# %%
#cleaned_df_sample.to_csv("cleaned-sample.csv", index=False)

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# id                   0
# category             0
# title                0
# body                 0
# amenities        16044
# bathrooms           63
# bedrooms           124
# currency             0
# fee                  0
# has_photo            0
# pets_allowed     60424
# price                1
# price_display        1
# price_type           0
# square_feet          0
# address          91549
# cityname           302
# state              302
# latitude            25
# longitude           25
# source               0
# time                 0
# dtype: int64

# %%
# Renamed columns for latitude/longitude degrees
df.rename(columns={'latitude': 'latitude_deg', 'longitude': 'longitude_deg'}, inplace=True)

# Ensured consistent data types
df['price'] = df['price'].astype(float)
df['time'] = pd.to_datetime(df['time'], unit='s')

# Dropped rows with missing values
df.dropna(inplace=True)

# %%
len(df.index)
# Out:
# 2932

# %%
#made a subset
subset_df_sample = df.sample(n=20, ignore_index=True)
subset_df_sample.head()
# Out:
#            id                category                                title  \
# 0  5668610637  housing/rent/apartment       Three BR 16815 Shrub Oak Drive
# 1  5668618016  housing/rent/apartment  One BR 19216 Dr. John Lambert Drive
# 2  5668624113  housing/rent/apartment    Studio apartment 2238 Hyde Street
# 3  5145459450  housing/rent/apartment                        3431 Congo Dr
# 4  5648133316  housing/rent/apartment         One BR 5140 S Graystone Ave.
#
#                                                 body  \
# 0  This unit is located at 16815 Shrub Oak Drive,...
# 1  This unit is located at 19216 Dr. John Lambert...
# 2  This unit is located at 2238 Hyde Street, San ...
# 3  Colorado Springs Easy access to the plumbing a...
# 4  This unit is located at 5140 S Graystone Ave.,...
#
#                                            amenities bathrooms bedrooms  \
# 0                            Dishwasher,Refrigerator         2        3
# ...

# %%
df.to_csv("cleaned_sample.csv", index=False)
